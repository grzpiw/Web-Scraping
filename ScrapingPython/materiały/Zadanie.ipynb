# %% [markdown]
# Stwórz system do pobierania danych z serwisu https://otodom.pl oraz zapisu ich w bazie danych. Funkcjonalności, które powinny zostać zaimplementowane to:
# - Jedna tabela przechowująca dane. Każdy wiersz odpowiada jednej ofercie. Cechy (kolumny w tabeli) każdego domu mogą zostać dobrane wedle uznania
# - Skrypty pozwalające: utworzyć pustą tabelę jeśli ta nie istnieje, usunąć tabelę jeśli ta istnieje, usunąć wszystkie rekordy z tabeli jeśli ta istnieje ale z zachowaniem samej tabeli
#
# // wspólne sprawdzenie
#
# - Scraper, który pobierze wszystkie lub wybrane oferty na podstawie zadanych filtrów
# - Skrypt, który wywoła wyżej opisany scraper i jednocześnie pozwoli zapisać pobrane dane do tabeli
#
# // wspólne sprawdzenie
#
# - Skrypt, który pozwoli podmienić pojedynczą wartość w tabeli pytając użytkownika która wartość ma to być i co należy wstawić w zamian
# - Skrypt, który w podobny sposób jak poprzedni pozwoli wyciągnąć dane z tabeli za pomocą zapytania SELECT
#
# Po zrealizowaniu każdych dwóch punktów z powyższej listy nastąpi weryfikacja wyników i odpowiedź na ewentualne pytania.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://zerazza.com/'
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}
response = requests.get(url,headers = headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 9 ]> <html lang="sv-SE" class="ie9 loading-site no-js"> <![endif]-->
# <!--[if IE 8 ]> <html lang="sv-SE" class="ie8 loading-site no-js"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--><html class="loading-site no-js" lang="sv-SE"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://zerazza.com/xmlrpc.php" rel="pingback"/>
# <script>(function(html){html.className = html.className.replace(/\bno-js\b/,'js')})(document.documentElement);</script>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <!-- This site is optimized with the Yoast SEO Premium plugin v18.4 (Yoast SEO v18.8) - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Köksprodukter &amp; köksgeråd online | Allt till ditt kök | Zerazza</title>
# ...

# %%
category_list = []
cat_main = soup.find_all("ul", class_="ubermenu-row")
cat_url = cat_main[0].find("a", class_="ubermenu-target").attrs["href"]
cat_name = cat_main[0].find("span", class_="ubermenu-target-title").text
cat_full = cat_url , cat_name

# %%
for cat in cat_full:
    cat_url = cat_main[0].find("a", class_="ubermenu-target").attrs["href"]
    cat_name = cat_main[0].find("span", class_="ubermenu-target-title").text
